# %%
import warnings
warnings.simplefilter('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pt
# %matplotlib inline

# %%
mb=pd.read_csv("C:\\Users\\ARM\\OneDrive\\Desktop\\winequality-red (1).csv")

# %%
mb
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
mb.shape
# Out:
# (1599, 12)

# %%
mb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
predict=mb.drop(["fixed acidity","volatile acidity","citric acid","residual sugar","chlorides","free sulfur dioxide","total sulfur dioxide","density","pH","sulphates"],axis=1)

# %%
predict
# Out:
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 2 columns]

# %%
x=predict.iloc[:,0].values.reshape(-1,1)
y=predict.iloc[:,1].values.reshape(-1,1)

# %%
x
# Out:
# array([[ 9.4],
#        [ 9.8],
#        [ 9.8],
#        ...,
#        [11. ],
#        [10.2],
#        [11. ]])

# %%
y
# Out:
# array([[5],
#        [5],
#        [5],
#        ...,
#        [6],
#        [5],
#        [6]], dtype=int64)

# %%
pt.scatter(x,y)
pt.xlabel('alcohol')
pt.ylabel('quality')
pt.title('linear reg')
pt.show()

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,train_size=0.6,random_state=0)

# %%
X_train.shape
# Out:
# (959, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
X_train
# Out:
# array([[ 9.4       ],
#        [ 9.4       ],
#        [10.5       ],
#        [ 9.5       ],
#        [10.9       ],
#        [ 9.4       ],
#        [ 9.7       ],
#        [13.        ],
#        [ 9.8       ],
#        [10.4       ],
#        [ 9.3       ],
#        [ 9.8       ],
#        [10.3       ],
#        [11.2       ],
#        [10.1       ],
#        [11.8       ],
#        [10.        ],
#        [ 9.5       ],
#        [ 9.6       ],
#        [10.5       ],
#        [ 9.4       ],
#        [ 9.3       ],
#        [11.4       ],
#        [ 9.        ],
#        [11.9       ],
#        [ 9.4       ],
#        [ 9.2       ],
#        [11.3       ],
#        [10.4       ],
#        [11.3       ],
#        [10.2       ],
#        [ 9.2       ],
#        [10.9       ],
#        [ 9.9       ],
#        [10.2       ],
#        [ 9.7       ],
#        [ 9.3       ],
#        [11.4       ],
#        [ 9.4       ],
#        [ 9.8       ],
#        [11.2       ],
# ...

# %%
Y_train
# Out:
# array([[6],
#        [5],
#        [5],
#        [6],
#        [6],
#        [6],
#        [6],
#        [7],
#        [5],
#        [7],
#        [5],
#        [6],
#        [5],
#        [6],
#        [4],
#        [6],
#        [5],
#        [5],
#        [6],
#        [7],
#        [6],
#        [4],
#        [6],
#        [6],
#        [7],
#        [6],
#        [5],
#        [6],
#        [6],
#        [8],
#        [5],
#        [5],
#        [5],
#        [5],
#        [5],
#        [6],
#        [5],
#        [8],
#        [5],
#        [5],
#        [7],
#        [7],
#        [6],
#        [5],
#        [5],
#        [5],
#        [5],
#        [6],
#        [8],
#        [7],
#        [6],
#        [5],
#        [5],
#        [5],
#        [7],
#        [6],
#        [6],
#        [5],
#        [5],
#        [6],
#        [7],
#        [6],
#        [5],
#        [5],
#        [6],
#        [6],
#        [6],
#        [4],
#        [5],
#        [6],
#        [7],
# ...

# %%
lm.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_predict=lm.predict(X_test)

# %%
y_predict
# Out:
# array([[5.81439367],
#        [5.36731718],
#        [6.14970104],
#        [5.51634268],
#        [5.66536818],
#        [5.18103531],
#        [5.4790863 ],
#        [5.85165005],
#        [5.36731718],
#        [5.25554806],
#        [5.29280443],
#        [5.59085543],
#        [5.7771373 ],
#        [6.07518829],
#        [5.59085543],
#        [6.03793192],
#        [6.55952116],
#        [5.70262455],
#        [6.29872654],
#        [5.14377893],
#        [6.52226479],
#        [5.29280443],
#        [5.70262455],
#        [6.07518829],
#        [5.44182993],
#        [5.4790863 ],
#        [5.40457356],
#        [6.29872654],
#        [5.29280443],
#        [6.55952116],
#        [5.66536818],
#        [5.81439367],
#        [5.73988092],
#        [5.4790863 ],
#        [6.37323929],
#        [5.96341917],
#        [5.25554806],
#        [5.29280443],
#        [6.41049566],
#        [5.88890642],
#        [5.44182993],
#        [5.96341917],
#        [6.85757216],
# ...

# %%
lr=pd.DataFrame(X_test,columns=['alcohol'])

# %%
lr
# Out:
#      alcohol
# 0       10.8
# 1        9.6
# 2       11.7
# 3       10.0
# 4       10.4
# ..       ...
# 635     12.2
# 636      9.4
# 637      9.7
# 638     10.1
# 639      8.7
#
# [640 rows x 1 columns]

# %%
lr['quality']=Y_test

# %%
lr
# Out:
#      alcohol  quality
# 0       10.8        6
# 1        9.6        5
# 2       11.7        7
# 3       10.0        6
# 4       10.4        5
# ..       ...      ...
# 635     12.2        6
# 636      9.4        6
# 637      9.7        5
# 638     10.1        7
# 639      8.7        6
#
# [640 rows x 2 columns]

# %%
lr['PRDDATA']=y_predict

# %%
lr
# Out:
#      alcohol  quality   PRDDATA
# 0       10.8        6  5.814394
# 1        9.6        5  5.367317
# 2       11.7        7  6.149701
# 3       10.0        6  5.516343
# 4       10.4        5  5.665368
# ..       ...      ...       ...
# 635     12.2        6  6.335983
# 636      9.4        6  5.292804
# 637      9.7        5  5.404574
# 638     10.1        7  5.553599
# 639      8.7        6  5.032010
#
# [640 rows x 3 columns]

# %%
pt.scatter(x,y,color='firebrick')
pt.plot(X_test,y_predict,color='black')
pt.xlabel('alcohol')
pt.ylabel('quality')
pt.title('linear reg')
pt.show()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
mean_squared_error(Y_test,y_predict)
# Out:
# 0.4739986315851036

# %%
mean_absolute_error(Y_test,y_predict)
# Out:
# 0.5388879747779874

# %%
r2_score(Y_test,y_predict)
# Out:
# 0.2043528492213248
